# %%
# !pip3 install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 8.7 MB 454 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 403 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.3 MB 416 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.4 MB 354 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 181 kB/s eta 0:00:01
# ...
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# ...
#      |████████████████████████████████| 857 kB 527 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 412 kB 505 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 207 kB 515 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 27.2 MB 382 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 6.9 MB 315 kB/s eta 0:00:01     |▊                               | 163 kB 328 kB/s eta 0:00:21
# ...

# %%
import streamlit as st

st.title('Hello, Streamlit!')
st.write('Đây là ứng dụng web đầu tiên của bạn với Streamlit.')
